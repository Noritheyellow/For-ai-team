# %% [markdown]
# # MIMIC-III WFDB Extraction
#
# [1] 에서 추출한 `record_names` 를 가져오고, 그 중에서 본 연구의 요구사항에 부합하는 환자들을 추려낸다.
# 본 연구의 요구사항은 이하와 같다:
# - `24h ~ 48h` 사이의 연속적인 데이터
# - `125Hz` 의 `ABP` 와 `PPG` 를 포함한 생물학적 신호
# - MIMIC DB 의 45 명의 기록 + MIMIC WFDB 의 55 명의 기록 = 총 100 명의 ABP, PPG 신호를 가진 데이터
#     - 위에 데이터 중 45 명의 기록은 MIMIC CDB 상에 위치한 데이터를 말하는 건가?
#     - 아니면 MIMIC WFDB 에 대응하여 존재하는 CDB 의 환자 수가 45 명이고 이에 대응되지 않는 환자가 55 명이라는 뜻인가?
#
# **References**
# - [1] `/root/Workspace/Reproduction-An-Estimation-method-of-Continuous-Non-Invasive-ABP-Waveform-using-PPG/src/00_mimiciii_dataset.ipynb`

# %%
import os
import re
import pickle
import gzip
import numpy as np
import asyncio
import multiprocessing
import wfdb
import matplotlib.pyplot as plt
import logging
from datetime import date

# %matplotlib inline
plt.style.use('ggplot')

log_format = '%(levelname)s %(asctime)s - %(message)s'
logging.basicConfig(
    filename=f'/root/Workspace/ppg2bp/Reproduction-An-Estimation-method-of-Continuous-Non-Invasive-ABP-Waveform-using-PPG/resources/logs/arca-{date.today().strftime("%b-%d-%Y")}.log',
    filemode='w',
    format=log_format,
    level=logging.DEBUG
)
logger = logging.getLogger()

CDB_PATH = '/root/Workspace/DataLake/mimic-iii_cdb/files/mimiciii/1.4/'
WFDB_PATH = '/root/Workspace/DataLake/mimic-iii_wfdb/'

logger.debug('Initiate 10_mimiciii_extract_dataset.ipynb')

# %%
with gzip.open('/root/Workspace/DataWarehouse/mimic-iii_wfdb/all_patient_records.pickle.gzip', 'rb') as f:
    record_names = pickle.load(f)

# verification
sum([len(record_names[i]) for i in range(len(record_names))])
# Out:
# 10282

# %%
# untangled list 
new_record_names = list(map(lambda recs: np.concatenate(np.asarray(recs, dtype=object), axis=0), record_names))
# NUMERIC data 는 굳이 볼 필요는 없다.
sep_signal_regex = re.compile('/root/Workspace/DataLake/mimic-iii_wfdb/p[0-9]{2}/p[0-9]{6}/p[0-9]{6}-[0-9]{4}[0-9\-]+.hea')
waveform_record_names = [list(filter(lambda rec: sep_signal_regex.match(rec) != None, new_record_names[i])) for i in range(len(new_record_names))]

# %%
print(len(waveform_record_names))
waveform_record_names[0][0:10]
# Out:
# 10
# ['/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064100/p064100-2191-02-24-16-30.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065490/p065490-2175-07-06-16-28.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065490/p065490-2175-07-06-12-21.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068543/p068543-2174-02-20-14-13.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067154/p067154-2138-04-23-15-03.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067154/p067154-2138-04-08-08-33.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067154/p067154-2138-04-13-17-59.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061949/p061949-2162-11-08-17-49.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061949/p061949-2162-11-07-08-10.hea',
#  '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067651/p067651-2182-05-11-00-23.hea']

# %% [markdown]
# ### Asyncio approach

# %%
async def get_record2(record_name, expression):
    loop = asyncio.get_running_loop()
    meta_regex = re.compile(expression)
    result = {
        'record_name': None,
        'subject_id': None,
        'base_date':  None,
        'sig_name':  None,
        'sig_len': None 
    }

    try:
        _, fields = await loop.run_in_executor(None, wfdb.rdsamp, record_name[:-4], 0, 1) # 지금 당장은 Signal value 가 필요없다.
        query_res = meta_regex.search(record_name)
        if all([signal_name in fields['sig_name'] for signal_name in ['PLETH', 'ABP']]):
            # record_name
            logger.debug(f'{query_res.groups()[0]} {fields["base_date"]} {fields["sig_name"]} saved!')
            result['record_name'] = record_name
            result['subject_id'] = query_res.groups()[0] 
            result['base_date'] = fields["base_date"]
            result['sig_name'] = fields["sig_name"]
            result['sig_len'] = fields["sig_len"]
        else:
            result = None
    except Exception as e:
        logger.debug(f'{e}')
        result = None

    return result 


async def runnable(waveform_record_name):
    tasks = [asyncio.create_task(get_record2(record_name, '([0-9]{6})-([0-9]{4}-[0-9]{2}-[0-9]{2})')) for record_name in waveform_record_name]
    results = await asyncio.gather(*tasks)
    return results

# %%
results = []
for i in range(len(waveform_record_names)):
    results.extend(await runnable(waveform_record_names[i]))

results = list(filter(lambda x: x!=None, results))

# %%
results
# Out:
# [{'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067154/p067154-2138-04-13-17-59.hea',
#   'subject_id': '067154',
#   'base_date': datetime.date(2138, 4, 13),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'MCL', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069082/p069082-2180-09-21-12-07.hea',
#   'subject_id': '069082',
#   'base_date': datetime.date(2180, 9, 21),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068425/p068425-2154-01-13-16-43.hea',
#   'subject_id': '068425',
#   'base_date': datetime.date(2154, 1, 13),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'CVP',
#    'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068116/p068116-2123-02-03-18-32.hea',
#   'subject_id': '068116',
#   'base_date': datetime.date(2123, 2, 3),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068116/p068116-2123-02-04-17-46.hea',
#   'subject_id': '068116',
#   'base_date': datetime.date(2123, 2, 4),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062798/p062798-2201-06-17-21-25.hea',
#   'subject_id': '062798',
#   'base_date': datetime.date(2201, 6, 17),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069925/p069925-2177-05-07-22-47.hea',
#   'subject_id': '069925',
#   'base_date': datetime.date(2177, 5, 7),
#   'sig_name': ['II', 'ABP', 'V', 'RESP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060181/p060181-2188-01-28-13-23.hea',
#   'subject_id': '060181',
#   'base_date': datetime.date(2188, 1, 28),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061149/p061149-2126-10-15-14-15.hea',
#   'subject_id': '061149',
#   'base_date': datetime.date(2126, 10, 15),
#   'sig_name': ['II', 'ABP', 'RESP', 'III', 'V', 'PLETH', 'MCL'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069233/p069233-2147-01-30-18-14.hea',
#   'subject_id': '069233',
#   'base_date': datetime.date(2147, 1, 30),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061663/p061663-2172-11-12-20-02.hea',
#   'subject_id': '061663',
#   'base_date': datetime.date(2172, 11, 12),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063226/p063226-2104-05-03-02-14.hea',
#   'subject_id': '063226',
#   'base_date': datetime.date(2104, 5, 3),
#   'sig_name': ['PLETH', 'II', 'III', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067763/p067763-2163-09-18-02-36.hea',
#   'subject_id': '067763',
#   'base_date': datetime.date(2163, 9, 18),
#   'sig_name': ['I', 'II', 'III', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067659/p067659-2179-07-08-12-01.hea',
#   'subject_id': '067659',
#   'base_date': datetime.date(2179, 7, 8),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067659/p067659-2179-07-06-01-15.hea',
#   'subject_id': '067659',
#   'base_date': datetime.date(2179, 7, 6),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067659/p067659-2179-07-13-18-28.hea',
#   'subject_id': '067659',
#   'base_date': datetime.date(2179, 7, 13),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061207/p061207-2108-07-31-10-28.hea',
#   'subject_id': '061207',
#   'base_date': datetime.date(2108, 7, 31),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061207/p061207-2108-07-28-23-30.hea',
#   'subject_id': '061207',
#   'base_date': datetime.date(2108, 7, 28),
#   'sig_name': ['II',
#    'AVR',
#    'AVL',
#    'AVF',
#    'V',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'UAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061207/p061207-2108-07-29-16-07.hea',
#   'subject_id': '061207',
#   'base_date': datetime.date(2108, 7, 29),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062232/p062232-2191-01-20-14-14.hea',
#   'subject_id': '062232',
#   'base_date': datetime.date(2191, 1, 20),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063771/p063771-2151-03-22-12-08.hea',
#   'subject_id': '063771',
#   'base_date': datetime.date(2151, 3, 22),
#   'sig_name': ['II', 'ABP', 'V', 'RESP', 'III', 'PLETH', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068703/p068703-2128-06-23-13-10.hea',
#   'subject_id': '068703',
#   'base_date': datetime.date(2128, 6, 23),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067475/p067475-2121-07-31-03-41.hea',
#   'subject_id': '067475',
#   'base_date': datetime.date(2121, 7, 31),
#   'sig_name': ['II', 'V', 'RESP', 'PLETH', 'ABP', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065050/p065050-2157-12-28-12-58.hea',
#   'subject_id': '065050',
#   'base_date': datetime.date(2157, 12, 28),
#   'sig_name': ['II', 'ABP', 'RESP', 'V', 'III', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062917/p062917-2181-03-26-12-05.hea',
#   'subject_id': '062917',
#   'base_date': datetime.date(2181, 3, 26),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062917/p062917-2181-03-27-02-30.hea',
#   'subject_id': '062917',
#   'base_date': datetime.date(2181, 3, 27),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067449/p067449-2110-02-18-14-21.hea',
#   'subject_id': '067449',
#   'base_date': datetime.date(2110, 2, 18),
#   'sig_name': ['I', 'ABP', 'RESP', 'II', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064067/p064067-2181-06-08-10-13.hea',
#   'subject_id': '064067',
#   'base_date': datetime.date(2181, 6, 8),
#   'sig_name': ['II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'CVP',
#    'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062824/p062824-2125-11-07-09-02.hea',
#   'subject_id': '062824',
#   'base_date': datetime.date(2125, 11, 7),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060641/p060641-2165-06-08-02-26.hea',
#   'subject_id': '060641',
#   'base_date': datetime.date(2165, 6, 8),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060641/p060641-2165-06-09-10-46.hea',
#   'subject_id': '060641',
#   'base_date': datetime.date(2165, 6, 9),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060641/p060641-2165-06-05-21-38.hea',
#   'subject_id': '060641',
#   'base_date': datetime.date(2165, 6, 5),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060641/p060641-2165-06-05-18-42.hea',
#   'subject_id': '060641',
#   'base_date': datetime.date(2165, 6, 5),
#   'sig_name': ['II', 'PLETH', 'I', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069579/p069579-2155-05-15-21-58.hea',
#   'subject_id': '069579',
#   'base_date': datetime.date(2155, 5, 15),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063938/p063938-2145-02-05-19-47.hea',
#   'subject_id': '063938',
#   'base_date': datetime.date(2145, 2, 5),
#   'sig_name': ['ABP', 'PLETH', 'II', 'I', 'RESP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063938/p063938-2145-02-05-03-16.hea',
#   'subject_id': '063938',
#   'base_date': datetime.date(2145, 2, 5),
#   'sig_name': ['II', 'V', 'PLETH', 'ART', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063938/p063938-2145-02-05-16-20.hea',
#   'subject_id': '063938',
#   'base_date': datetime.date(2145, 2, 5),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063701/p063701-2147-01-23-19-12.hea',
#   'subject_id': '063701',
#   'base_date': datetime.date(2147, 1, 23),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060987/p060987-2103-08-16-17-37.hea',
#   'subject_id': '060987',
#   'base_date': datetime.date(2103, 8, 16),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'CVP',
#    'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060987/p060987-2103-08-14-02-59.hea',
#   'subject_id': '060987',
#   'base_date': datetime.date(2103, 8, 14),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065476/p065476-2155-12-24-02-24.hea',
#   'subject_id': '065476',
#   'base_date': datetime.date(2155, 12, 24),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069250/p069250-2115-06-28-20-32.hea',
#   'subject_id': '069250',
#   'base_date': datetime.date(2115, 6, 28),
#   'sig_name': ['II', 'V', 'ABP', 'PLETH', 'RESP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069709/p069709-2106-04-09-16-25.hea',
#   'subject_id': '069709',
#   'base_date': datetime.date(2106, 4, 9),
#   'sig_name': ['II', 'PLETH', 'ABP', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069709/p069709-2106-04-07-16-00.hea',
#   'subject_id': '069709',
#   'base_date': datetime.date(2106, 4, 7),
#   'sig_name': ['II', 'PLETH', 'ABP', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069709/p069709-2106-04-10-22-06.hea',
#   'subject_id': '069709',
#   'base_date': datetime.date(2106, 4, 10),
#   'sig_name': ['ABP', 'PLETH', 'II', 'CVP', 'I', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066560/p066560-2168-01-05-23-56.hea',
#   'subject_id': '066560',
#   'base_date': datetime.date(2168, 1, 5),
#   'sig_name': ['II', 'ABP', 'PLETH', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061685/p061685-2136-02-29-16-41.hea',
#   'subject_id': '061685',
#   'base_date': datetime.date(2136, 2, 29),
#   'sig_name': ['II', 'ABP', 'V', 'RESP', 'III', 'I', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063710/p063710-2127-03-02-11-44.hea',
#   'subject_id': '063710',
#   'base_date': datetime.date(2127, 3, 2),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063710/p063710-2127-03-03-14-03.hea',
#   'subject_id': '063710',
#   'base_date': datetime.date(2127, 3, 3),
#   'sig_name': ['I',
#    'II',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'CVP',
#    'UAP',
#    'FAP',
#    'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063944/p063944-2121-08-04-17-12.hea',
#   'subject_id': '063944',
#   'base_date': datetime.date(2121, 8, 4),
#   'sig_name': ['II', 'ABP', 'PLETH', 'I', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063944/p063944-2121-07-23-02-13.hea',
#   'subject_id': '063944',
#   'base_date': datetime.date(2121, 7, 23),
#   'sig_name': ['II', 'V', 'ABP', 'PLETH', 'ART', 'CVP', 'III', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063944/p063944-2121-07-21-05-56.hea',
#   'subject_id': '063944',
#   'base_date': datetime.date(2121, 7, 21),
#   'sig_name': ['PLETH', 'II', 'V', 'ABP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060343/p060343-2186-11-24-14-46.hea',
#   'subject_id': '060343',
#   'base_date': datetime.date(2186, 11, 24),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060226/p060226-2184-04-09-16-25.hea',
#   'subject_id': '060226',
#   'base_date': datetime.date(2184, 4, 9),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060226/p060226-2184-04-10-17-52.hea',
#   'subject_id': '060226',
#   'base_date': datetime.date(2184, 4, 10),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060226/p060226-2184-04-07-21-34.hea',
#   'subject_id': '060226',
#   'base_date': datetime.date(2184, 4, 7),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068457/p068457-2129-07-28-19-03.hea',
#   'subject_id': '068457',
#   'base_date': datetime.date(2129, 7, 28),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062512/p062512-2140-06-03-14-02.hea',
#   'subject_id': '062512',
#   'base_date': datetime.date(2140, 6, 3),
#   'sig_name': ['II', 'ABP', 'RESP', 'aVR', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060949/p060949-2196-09-23-17-36.hea',
#   'subject_id': '060949',
#   'base_date': datetime.date(2196, 9, 23),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068710/p068710-2186-10-13-12-29.hea',
#   'subject_id': '068710',
#   'base_date': datetime.date(2186, 10, 13),
#   'sig_name': ['II', 'ABP', 'RESP', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064558/p064558-2146-05-21-22-44.hea',
#   'subject_id': '064558',
#   'base_date': datetime.date(2146, 5, 21),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067223/p067223-2121-08-01-21-00.hea',
#   'subject_id': '067223',
#   'base_date': datetime.date(2121, 8, 1),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063074/p063074-2189-05-31-21-06.hea',
#   'subject_id': '063074',
#   'base_date': datetime.date(2189, 5, 31),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069047/p069047-2192-01-10-22-57.hea',
#   'subject_id': '069047',
#   'base_date': datetime.date(2192, 1, 10),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069434/p069434-2125-02-05-16-02.hea',
#   'subject_id': '069434',
#   'base_date': datetime.date(2125, 2, 5),
#   'sig_name': ['ABP', 'PLETH', 'II'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069434/p069434-2125-02-04-06-21.hea',
#   'subject_id': '069434',
#   'base_date': datetime.date(2125, 2, 4),
#   'sig_name': ['PLETH', 'II', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069651/p069651-2194-07-21-12-27.hea',
#   'subject_id': '069651',
#   'base_date': datetime.date(2194, 7, 21),
#   'sig_name': ['II', 'ABP', 'III', 'RESP', 'V', 'MCL', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060409/p060409-2138-05-28-19-39.hea',
#   'subject_id': '060409',
#   'base_date': datetime.date(2138, 5, 28),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069182/p069182-2102-07-30-10-56.hea',
#   'subject_id': '069182',
#   'base_date': datetime.date(2102, 7, 30),
#   'sig_name': ['II', 'AVR', 'V', 'MCL', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069182/p069182-2102-07-31-14-48.hea',
#   'subject_id': '069182',
#   'base_date': datetime.date(2102, 7, 31),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068065/p068065-2196-05-17-01-49.hea',
#   'subject_id': '068065',
#   'base_date': datetime.date(2196, 5, 17),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068065/p068065-2196-05-17-12-21.hea',
#   'subject_id': '068065',
#   'base_date': datetime.date(2196, 5, 17),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'CVP',
#    'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068065/p068065-2197-03-05-14-39.hea',
#   'subject_id': '068065',
#   'base_date': datetime.date(2197, 3, 5),
#   'sig_name': ['PLETH', 'II', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068065/p068065-2197-03-06-00-17.hea',
#   'subject_id': '068065',
#   'base_date': datetime.date(2197, 3, 6),
#   'sig_name': ['II', 'PLETH', 'ABP', 'III', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068065/p068065-2196-05-17-10-56.hea',
#   'subject_id': '068065',
#   'base_date': datetime.date(2196, 5, 17),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066720/p066720-2128-08-24-16-58.hea',
#   'subject_id': '066720',
#   'base_date': datetime.date(2128, 8, 24),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP', 'UAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066720/p066720-2128-08-25-13-08.hea',
#   'subject_id': '066720',
#   'base_date': datetime.date(2128, 8, 25),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP', 'UAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066720/p066720-2128-08-14-16-36.hea',
#   'subject_id': '066720',
#   'base_date': datetime.date(2128, 8, 14),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'CVP',
#    'UAP',
#    'ART',
#    'UVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066264/p066264-2103-03-31-02-22.hea',
#   'subject_id': '066264',
#   'base_date': datetime.date(2103, 3, 31),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'II+'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068836/p068836-2148-07-14-13-04.hea',
#   'subject_id': '068836',
#   'base_date': datetime.date(2148, 7, 14),
#   'sig_name': ['II', 'V', 'ABP', 'PLETH', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067245/p067245-2134-01-18-16-32.hea',
#   'subject_id': '067245',
#   'base_date': datetime.date(2134, 1, 18),
#   'sig_name': ['ABP', 'RESP', 'II', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067245/p067245-2134-01-16-13-14.hea',
#   'subject_id': '067245',
#   'base_date': datetime.date(2134, 1, 16),
#   'sig_name': ['II', 'ABP', 'RESP', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060994/p060994-2119-07-17-12-53.hea',
#   'subject_id': '060994',
#   'base_date': datetime.date(2119, 7, 17),
#   'sig_name': ['ABP', 'RESP', 'II', 'V', 'CVP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067158/p067158-2153-01-15-13-46.hea',
#   'subject_id': '067158',
#   'base_date': datetime.date(2153, 1, 15),
#   'sig_name': ['II', 'ABP', 'RESP', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065180/p065180-2114-11-21-13-38.hea',
#   'subject_id': '065180',
#   'base_date': datetime.date(2114, 11, 21),
#   'sig_name': ['II', 'III', 'AVR', 'AVL', 'V', 'MCL', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065180/p065180-2114-11-09-21-08.hea',
#   'subject_id': '065180',
#   'base_date': datetime.date(2114, 11, 9),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'AVF',
#    'V',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'CVP',
#    'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068464/p068464-2160-09-13-02-05.hea',
#   'subject_id': '068464',
#   'base_date': datetime.date(2160, 9, 13),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068464/p068464-2160-09-12-13-28.hea',
#   'subject_id': '068464',
#   'base_date': datetime.date(2160, 9, 12),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066105/p066105-2177-10-05-20-52.hea',
#   'subject_id': '066105',
#   'base_date': datetime.date(2177, 10, 5),
#   'sig_name': ['II',
#    'III',
#    'AVR',
#    'V',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'ICP',
#    'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066105/p066105-2177-10-22-16-10.hea',
#   'subject_id': '066105',
#   'base_date': datetime.date(2177, 10, 22),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068391/p068391-2144-03-26-14-49.hea',
#   'subject_id': '068391',
#   'base_date': datetime.date(2144, 3, 26),
#   'sig_name': ['MCL', 'II', 'PLETH', 'V', 'I', 'III', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063130/p063130-2102-05-19-10-59.hea',
#   'subject_id': '063130',
#   'base_date': datetime.date(2102, 5, 19),
#   'sig_name': ['II', 'AVR', 'V', 'MCL', 'RESP', 'PLETH', 'ABP', 'ICP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061213/p061213-2148-11-11-11-48.hea',
#   'subject_id': '061213',
#   'base_date': datetime.date(2148, 11, 11),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP', 'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061213/p061213-2148-11-06-12-59.hea',
#   'subject_id': '061213',
#   'base_date': datetime.date(2148, 11, 6),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'CVP',
#    'UAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061213/p061213-2148-11-13-22-37.hea',
#   'subject_id': '061213',
#   'base_date': datetime.date(2148, 11, 13),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061213/p061213-2148-11-08-19-46.hea',
#   'subject_id': '061213',
#   'base_date': datetime.date(2148, 11, 8),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063063/p063063-2197-02-23-17-37.hea',
#   'subject_id': '063063',
#   'base_date': datetime.date(2197, 2, 23),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065759/p065759-2110-07-23-15-50.hea',
#   'subject_id': '065759',
#   'base_date': datetime.date(2110, 7, 23),
#   'sig_name': ['ABP', 'PLETH', 'II', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068915/p068915-2197-11-02-12-41.hea',
#   'subject_id': '068915',
#   'base_date': datetime.date(2197, 11, 2),
#   'sig_name': ['II', 'III', 'V', 'RESP', 'PLETH', 'ABP', 'ART', 'IC1'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065370/p065370-2190-11-27-13-46.hea',
#   'subject_id': '065370',
#   'base_date': datetime.date(2190, 11, 27),
#   'sig_name': ['ABP', 'RESP', 'I', 'MCL', 'II', 'V', 'CVP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p069464/p069464-2191-06-02-00-49.hea',
#   'subject_id': '069464',
#   'base_date': datetime.date(2191, 6, 2),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065861/p065861-2191-03-04-17-17.hea',
#   'subject_id': '065861',
#   'base_date': datetime.date(2191, 3, 4),
#   'sig_name': ['II', 'ABP', 'RESP', 'III', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062380/p062380-2174-09-23-16-44.hea',
#   'subject_id': '062380',
#   'base_date': datetime.date(2174, 9, 23),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068964/p068964-2163-05-16-18-26.hea',
#   'subject_id': '068964',
#   'base_date': datetime.date(2163, 5, 16),
#   'sig_name': ['PLETH', 'II', 'ABP', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068964/p068964-2163-05-15-12-09.hea',
#   'subject_id': '068964',
#   'base_date': datetime.date(2163, 5, 15),
#   'sig_name': ['PLETH', 'II', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066811/p066811-2114-08-13-14-44.hea',
#   'subject_id': '066811',
#   'base_date': datetime.date(2114, 8, 13),
#   'sig_name': ['II', 'ABP', 'RESP', 'III', 'CVP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063552/p063552-2137-12-29-22-31.hea',
#   'subject_id': '063552',
#   'base_date': datetime.date(2137, 12, 29),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068611/p068611-2168-11-11-07-50.hea',
#   'subject_id': '068611',
#   'base_date': datetime.date(2168, 11, 11),
#   'sig_name': ['II', 'PLETH', 'ABP', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063113/p063113-2186-08-04-16-19.hea',
#   'subject_id': '063113',
#   'base_date': datetime.date(2186, 8, 4),
#   'sig_name': ['PLETH', 'II', 'ABP', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064717/p064717-2105-09-05-08-33.hea',
#   'subject_id': '064717',
#   'base_date': datetime.date(2105, 9, 5),
#   'sig_name': ['II', 'PLETH', 'V', 'RESP', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064717/p064717-2105-09-03-12-58.hea',
#   'subject_id': '064717',
#   'base_date': datetime.date(2105, 9, 3),
#   'sig_name': ['ABP', 'RESP', 'II', 'V', 'MCL', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064717/p064717-2105-09-05-10-47.hea',
#   'subject_id': '064717',
#   'base_date': datetime.date(2105, 9, 5),
#   'sig_name': ['II', 'ABP', 'RESP', 'V', 'PLETH', 'MCL', 'I', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062717/p062717-2145-11-22-10-28.hea',
#   'subject_id': '062717',
#   'base_date': datetime.date(2145, 11, 22),
#   'sig_name': ['ART', 'II', 'ABP', 'V', 'RESP', 'I', 'III', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068902/p068902-2145-11-17-12-31.hea',
#   'subject_id': '068902',
#   'base_date': datetime.date(2145, 11, 17),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066677/p066677-2173-06-13-19-57.hea',
#   'subject_id': '066677',
#   'base_date': datetime.date(2173, 6, 13),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062259/p062259-2144-10-21-16-11.hea',
#   'subject_id': '062259',
#   'base_date': datetime.date(2144, 10, 21),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062259/p062259-2144-07-01-16-08.hea',
#   'subject_id': '062259',
#   'base_date': datetime.date(2144, 7, 1),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066483/p066483-2190-12-29-08-24.hea',
#   'subject_id': '066483',
#   'base_date': datetime.date(2190, 12, 29),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066483/p066483-2190-12-29-16-08.hea',
#   'subject_id': '066483',
#   'base_date': datetime.date(2190, 12, 29),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060274/p060274-2132-11-27-13-49.hea',
#   'subject_id': '060274',
#   'base_date': datetime.date(2132, 11, 27),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'AVL',
#    'AVF',
#    'V',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'CVP',
#    'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065675/p065675-2133-02-18-20-30.hea',
#   'subject_id': '065675',
#   'base_date': datetime.date(2133, 2, 18),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062298/p062298-2164-06-15-09-00.hea',
#   'subject_id': '062298',
#   'base_date': datetime.date(2164, 6, 15),
#   'sig_name': ['II', 'AVR', 'MCL', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p062298/p062298-2164-06-14-11-47.hea',
#   'subject_id': '062298',
#   'base_date': datetime.date(2164, 6, 14),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'MCL', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063368/p063368-2197-06-02-20-07.hea',
#   'subject_id': '063368',
#   'base_date': datetime.date(2197, 6, 2),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063762/p063762-2181-12-04-03-58.hea',
#   'subject_id': '063762',
#   'base_date': datetime.date(2181, 12, 4),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063201/p063201-2200-09-02-22-32.hea',
#   'subject_id': '063201',
#   'base_date': datetime.date(2200, 9, 2),
#   'sig_name': ['PLETH', 'I', 'II', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063201/p063201-2200-08-31-02-11.hea',
#   'subject_id': '063201',
#   'base_date': datetime.date(2200, 8, 31),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063201/p063201-2200-08-31-14-41.hea',
#   'subject_id': '063201',
#   'base_date': datetime.date(2200, 8, 31),
#   'sig_name': ['ABP', 'PLETH', 'II'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063201/p063201-2200-09-05-18-43.hea',
#   'subject_id': '063201',
#   'base_date': datetime.date(2200, 9, 5),
#   'sig_name': ['II', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063201/p063201-2200-08-31-07-48.hea',
#   'subject_id': '063201',
#   'base_date': datetime.date(2200, 8, 31),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'UAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060614/p060614-2175-09-29-15-37.hea',
#   'subject_id': '060614',
#   'base_date': datetime.date(2175, 9, 29),
#   'sig_name': ['II', 'ABP', 'III', 'RESP', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066878/p066878-2172-03-16-17-27.hea',
#   'subject_id': '066878',
#   'base_date': datetime.date(2172, 3, 16),
#   'sig_name': ['II', 'PLETH', 'ABP', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066878/p066878-2172-03-17-19-01.hea',
#   'subject_id': '066878',
#   'base_date': datetime.date(2172, 3, 17),
#   'sig_name': ['II', 'ABP', 'PLETH', 'I', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065665/p065665-2180-10-26-23-46.hea',
#   'subject_id': '065665',
#   'base_date': datetime.date(2180, 10, 26),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064970/p064970-2123-01-29-11-47.hea',
#   'subject_id': '064970',
#   'base_date': datetime.date(2123, 1, 29),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060892/p060892-2170-08-29-14-20.hea',
#   'subject_id': '060892',
#   'base_date': datetime.date(2170, 8, 29),
#   'sig_name': ['II', 'ABP', 'V', 'RESP', 'I', 'aVF', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060432/p060432-2141-07-09-09-16.hea',
#   'subject_id': '060432',
#   'base_date': datetime.date(2141, 7, 9),
#   'sig_name': ['ABP', 'PLETH', 'II', 'I', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060432/p060432-2141-07-14-14-13.hea',
#   'subject_id': '060432',
#   'base_date': datetime.date(2141, 7, 14),
#   'sig_name': ['I', 'PLETH', 'ABP', 'II'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060432/p060432-2141-07-09-05-19.hea',
#   'subject_id': '060432',
#   'base_date': datetime.date(2141, 7, 9),
#   'sig_name': ['II', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060432/p060432-2141-07-20-21-29.hea',
#   'subject_id': '060432',
#   'base_date': datetime.date(2141, 7, 20),
#   'sig_name': ['I', 'PLETH', 'ABP', 'II', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060432/p060432-2141-07-19-14-05.hea',
#   'subject_id': '060432',
#   'base_date': datetime.date(2141, 7, 19),
#   'sig_name': ['I', 'PLETH', 'ABP', 'II'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065925/p065925-2112-05-16-14-22.hea',
#   'subject_id': '065925',
#   'base_date': datetime.date(2112, 5, 16),
#   'sig_name': ['II', 'V', 'ABP', 'CVP', 'PLETH', 'RESP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p060961/p060961-2142-06-18-21-17.hea',
#   'subject_id': '060961',
#   'base_date': datetime.date(2142, 6, 18),
#   'sig_name': ['II', 'ABP', 'PLETH', 'III', 'I', 'CVP', 'V'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061877/p061877-2158-07-26-21-57.hea',
#   'subject_id': '061877',
#   'base_date': datetime.date(2158, 7, 26),
#   'sig_name': ['I', 'II', 'III', 'V', 'RESP', 'PLETH', 'ABP', 'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068450/p068450-2102-03-15-19-29.hea',
#   'subject_id': '068450',
#   'base_date': datetime.date(2102, 3, 15),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063486/p063486-2153-12-14-22-38.hea',
#   'subject_id': '063486',
#   'base_date': datetime.date(2153, 12, 14),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063486/p063486-2153-12-12-23-21.hea',
#   'subject_id': '063486',
#   'base_date': datetime.date(2153, 12, 12),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063486/p063486-2153-12-15-17-07.hea',
#   'subject_id': '063486',
#   'base_date': datetime.date(2153, 12, 15),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061118/p061118-2136-07-25-13-11.hea',
#   'subject_id': '061118',
#   'base_date': datetime.date(2136, 7, 25),
#   'sig_name': ['II', 'ABP', 'V', 'RESP', 'MCL', 'CVP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065240/p065240-2114-12-29-12-47.hea',
#   'subject_id': '065240',
#   'base_date': datetime.date(2114, 12, 29),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065240/p065240-2114-12-27-22-02.hea',
#   'subject_id': '065240',
#   'base_date': datetime.date(2114, 12, 27),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065240/p065240-2114-12-29-10-38.hea',
#   'subject_id': '065240',
#   'base_date': datetime.date(2114, 12, 29),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065849/p065849-2134-01-13-16-44.hea',
#   'subject_id': '065849',
#   'base_date': datetime.date(2134, 1, 13),
#   'sig_name': ['PLETH', 'II', 'V', 'III', 'MCL', 'ABP', 'aVL'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064700/p064700-2117-11-10-13-27.hea',
#   'subject_id': '064700',
#   'base_date': datetime.date(2117, 11, 10),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061928/p061928-2110-01-10-13-46.hea',
#   'subject_id': '061928',
#   'base_date': datetime.date(2110, 1, 10),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068300/p068300-2143-09-06-12-15.hea',
#   'subject_id': '068300',
#   'base_date': datetime.date(2143, 9, 6),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068300/p068300-2143-08-31-17-57.hea',
#   'subject_id': '068300',
#   'base_date': datetime.date(2143, 8, 31),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068300/p068300-2143-09-02-10-29.hea',
#   'subject_id': '068300',
#   'base_date': datetime.date(2143, 9, 2),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068300/p068300-2143-09-06-22-08.hea',
#   'subject_id': '068300',
#   'base_date': datetime.date(2143, 9, 6),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068300/p068300-2143-09-03-22-24.hea',
#   'subject_id': '068300',
#   'base_date': datetime.date(2143, 9, 3),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068300/p068300-2143-08-31-09-57.hea',
#   'subject_id': '068300',
#   'base_date': datetime.date(2143, 8, 31),
#   'sig_name': ['II', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067415/p067415-2176-11-25-12-19.hea',
#   'subject_id': '067415',
#   'base_date': datetime.date(2176, 11, 25),
#   'sig_name': ['ABP', 'RESP', 'II', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068242/p068242-2106-09-27-09-15.hea',
#   'subject_id': '068242',
#   'base_date': datetime.date(2106, 9, 27),
#   'sig_name': ['II', 'ABP', 'RESP', 'III', 'I', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068949/p068949-2144-01-27-22-47.hea',
#   'subject_id': '068949',
#   'base_date': datetime.date(2144, 1, 27),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068949/p068949-2140-09-15-18-06.hea',
#   'subject_id': '068949',
#   'base_date': datetime.date(2140, 9, 15),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'ART', 'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065824/p065824-2132-09-22-19-16.hea',
#   'subject_id': '065824',
#   'base_date': datetime.date(2132, 9, 22),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066696/p066696-2119-05-26-13-53.hea',
#   'subject_id': '066696',
#   'base_date': datetime.date(2119, 5, 26),
#   'sig_name': ['II', 'ABP', 'RESP', 'V', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064798/p064798-2172-08-12-19-03.hea',
#   'subject_id': '064798',
#   'base_date': datetime.date(2172, 8, 12),
#   'sig_name': ['II', 'AVR', 'MCL', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064798/p064798-2172-08-05-08-38.hea',
#   'subject_id': '064798',
#   'base_date': datetime.date(2172, 8, 5),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'AOBP',
#    'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067533/p067533-2151-09-18-20-15.hea',
#   'subject_id': '067533',
#   'base_date': datetime.date(2151, 9, 18),
#   'sig_name': ['II', 'PLETH', 'ABP', 'III', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067533/p067533-2151-09-17-01-02.hea',
#   'subject_id': '067533',
#   'base_date': datetime.date(2151, 9, 17),
#   'sig_name': ['II', 'ABP', 'PLETH', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p067533/p067533-2151-09-17-17-36.hea',
#   'subject_id': '067533',
#   'base_date': datetime.date(2151, 9, 17),
#   'sig_name': ['I', 'II', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061030/p061030-2194-06-14-16-50.hea',
#   'subject_id': '061030',
#   'base_date': datetime.date(2194, 6, 14),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061030/p061030-2194-06-14-16-52.hea',
#   'subject_id': '061030',
#   'base_date': datetime.date(2194, 6, 14),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP', 'UAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061030/p061030-2194-06-13-16-38.hea',
#   'subject_id': '061030',
#   'base_date': datetime.date(2194, 6, 13),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p066899/p066899-2144-10-20-14-32.hea',
#   'subject_id': '066899',
#   'base_date': datetime.date(2144, 10, 20),
#   'sig_name': ['II', 'ABP', 'V', 'RESP', 'I', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p063741/p063741-2125-01-27-21-26.hea',
#   'subject_id': '063741',
#   'base_date': datetime.date(2125, 1, 27),
#   'sig_name': ['II', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064771/p064771-2126-06-23-17-25.hea',
#   'subject_id': '064771',
#   'base_date': datetime.date(2126, 6, 23),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064771/p064771-2126-06-22-17-25.hea',
#   'subject_id': '064771',
#   'base_date': datetime.date(2126, 6, 22),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064771/p064771-2126-06-22-04-04.hea',
#   'subject_id': '064771',
#   'base_date': datetime.date(2126, 6, 22),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p065006/p065006-2106-03-09-22-52.hea',
#   'subject_id': '065006',
#   'base_date': datetime.date(2106, 3, 9),
#   'sig_name': ['I', 'II', 'AVR', 'AVF', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p068875/p068875-2160-08-11-15-30.hea',
#   'subject_id': '068875',
#   'base_date': datetime.date(2160, 8, 11),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p061729/p061729-2180-08-01-13-37.hea',
#   'subject_id': '061729',
#   'base_date': datetime.date(2180, 8, 1),
#   'sig_name': ['II', 'ABP', 'RESP', 'III', 'V', 'I', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-05-28-15-03.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 5, 28),
#   'sig_name': ['II', 'V', 'ABP', 'PLETH', 'III', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-06-01-13-51.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 6, 1),
#   'sig_name': ['II', 'ABP', 'PLETH', 'III', 'I', 'V'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-06-05-17-28.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 6, 5),
#   'sig_name': ['II', 'V', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-06-01-08-28.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 6, 1),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-06-04-16-08.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 6, 4),
#   'sig_name': ['II', 'V', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-05-29-14-59.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 5, 29),
#   'sig_name': ['ABP', 'PLETH', 'III', 'II', 'I'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-06-25-21-25.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 6, 25),
#   'sig_name': ['ABP', 'PLETH', 'II'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-06-06-12-11.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 6, 6),
#   'sig_name': ['II', 'V', 'PLETH', 'ABP', 'III', 'I', 'RESP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p06/p064965/p064965-2131-05-30-23-02.hea',
#   'subject_id': '064965',
#   'base_date': datetime.date(2131, 5, 30),
# ...
#   'subject_id': '018846',
#   'base_date': datetime.date(2139, 12, 2),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018846/p018846-2139-12-04-15-03.hea',
#   'subject_id': '018846',
#   'base_date': datetime.date(2139, 12, 4),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018846/p018846-2144-03-19-11-28.hea',
#   'subject_id': '018846',
#   'base_date': datetime.date(2144, 3, 19),
#   'sig_name': ['PLETH', 'II', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018846/p018846-2144-03-29-02-58.hea',
#   'subject_id': '018846',
#   'base_date': datetime.date(2144, 3, 29),
#   'sig_name': ['II', 'ABP', 'PLETH', 'I', 'III', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018846/p018846-2139-11-28-21-10.hea',
#   'subject_id': '018846',
#   'base_date': datetime.date(2139, 11, 28),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'CVP',
#    'UAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018846/p018846-2139-12-11-10-19.hea',
#   'subject_id': '018846',
#   'base_date': datetime.date(2139, 12, 11),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018846/p018846-2144-03-22-18-22.hea',
#   'subject_id': '018846',
#   'base_date': datetime.date(2144, 3, 22),
#   'sig_name': ['II', 'III', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018846/p018846-2144-04-24-09-16.hea',
#   'subject_id': '018846',
#   'base_date': datetime.date(2144, 4, 24),
#   'sig_name': ['II', 'ABP', 'PLETH', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011187/p011187-2108-10-15-16-37.hea',
#   'subject_id': '011187',
#   'base_date': datetime.date(2108, 10, 15),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p019700/p019700-2157-05-18-17-40.hea',
#   'subject_id': '019700',
#   'base_date': datetime.date(2157, 5, 18),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018626/p018626-2146-04-06-19-54.hea',
#   'subject_id': '018626',
#   'base_date': datetime.date(2146, 4, 6),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011957/p011957-2137-03-20-10-11.hea',
#   'subject_id': '011957',
#   'base_date': datetime.date(2137, 3, 20),
#   'sig_name': ['II', 'III', 'MCL', 'RESP', 'PLETH', 'ABP', 'CVP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011957/p011957-2137-03-24-16-50.hea',
#   'subject_id': '011957',
#   'base_date': datetime.date(2137, 3, 24),
#   'sig_name': ['II', 'III', 'MCL', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p014755/p014755-2130-08-19-01-01.hea',
#   'subject_id': '014755',
#   'base_date': datetime.date(2130, 8, 19),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p014755/p014755-2130-08-19-00-58.hea',
#   'subject_id': '014755',
#   'base_date': datetime.date(2130, 8, 19),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p012788/p012788-2199-07-19-19-58.hea',
#   'subject_id': '012788',
#   'base_date': datetime.date(2199, 7, 19),
#   'sig_name': ['RESP', 'II', 'V', 'I', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013618/p013618-2206-02-27-15-00.hea',
#   'subject_id': '013618',
#   'base_date': datetime.date(2206, 2, 27),
#   'sig_name': ['PLETH', 'II', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p017122/p017122-2141-05-23-20-11.hea',
#   'subject_id': '017122',
#   'base_date': datetime.date(2141, 5, 23),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'MCL', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p010842/p010842-2155-03-13-02-26.hea',
#   'subject_id': '010842',
#   'base_date': datetime.date(2155, 3, 13),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p010842/p010842-2155-03-13-18-08.hea',
#   'subject_id': '010842',
#   'base_date': datetime.date(2155, 3, 13),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p010842/p010842-2155-03-12-20-12.hea',
#   'subject_id': '010842',
#   'base_date': datetime.date(2155, 3, 12),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p019726/p019726-2141-09-15-18-51.hea',
#   'subject_id': '019726',
#   'base_date': datetime.date(2141, 9, 15),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p012344/p012344-2122-02-14-08-49.hea',
#   'subject_id': '012344',
#   'base_date': datetime.date(2122, 2, 14),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013628/p013628-2126-02-10-05-00.hea',
#   'subject_id': '013628',
#   'base_date': datetime.date(2126, 2, 10),
#   'sig_name': ['ECG', 'II', 'PLETH', 'V', 'ABP', 'III', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013628/p013628-2126-02-15-17-29.hea',
#   'subject_id': '013628',
#   'base_date': datetime.date(2126, 2, 15),
#   'sig_name': ['II', 'ABP', 'PLETH', 'III', 'I', 'RESP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013628/p013628-2126-02-14-14-42.hea',
#   'subject_id': '013628',
#   'base_date': datetime.date(2126, 2, 14),
#   'sig_name': ['II', 'ABP', 'PLETH', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013628/p013628-2123-10-28-10-32.hea',
#   'subject_id': '013628',
#   'base_date': datetime.date(2123, 10, 28),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013628/p013628-2123-10-29-14-47.hea',
#   'subject_id': '013628',
#   'base_date': datetime.date(2123, 10, 29),
#   'sig_name': ['II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013628/p013628-2123-10-27-20-08.hea',
#   'subject_id': '013628',
#   'base_date': datetime.date(2123, 10, 27),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p017692/p017692-2208-01-21-18-34.hea',
#   'subject_id': '017692',
#   'base_date': datetime.date(2208, 1, 21),
#   'sig_name': ['II', 'PLETH', 'ABP', 'I', 'V', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p012632/p012632-2170-10-11-18-48.hea',
#   'subject_id': '012632',
#   'base_date': datetime.date(2170, 10, 11),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011388/p011388-2175-05-19-02-26.hea',
#   'subject_id': '011388',
#   'base_date': datetime.date(2175, 5, 19),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011388/p011388-2175-05-19-13-25.hea',
#   'subject_id': '011388',
#   'base_date': datetime.date(2175, 5, 19),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018254/p018254-2198-12-06-13-33.hea',
#   'subject_id': '018254',
#   'base_date': datetime.date(2198, 12, 6),
#   'sig_name': ['I', 'ABP', 'RESP', 'II', 'V', 'III', 'MCL', 'aVF', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-09-07-31.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 9),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-08-22-03.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 8),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2198-12-27-18-42.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2198, 12, 27),
#   'sig_name': ['PLETH', 'II', 'ABP', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-05-13-39.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 5),
#   'sig_name': ['II', 'PLETH', 'ABP', 'aVL', 'MCL'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-10-23-08.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 10),
#   'sig_name': ['II', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-08-11-43.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 8),
#   'sig_name': ['II', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-04-08-14.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 4),
#   'sig_name': ['II', 'PLETH', 'ABP', 'I', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-25-16-11.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 25),
#   'sig_name': ['aVR', 'PLETH', 'ABP', 'I', 'II', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-18-12-59.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 18),
#   'sig_name': ['II', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-18-18-18.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 18),
#   'sig_name': ['II', 'PLETH', 'ABP', 'I', 'aVR'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015046/p015046-2199-01-11-10-12.hea',
#   'subject_id': '015046',
#   'base_date': datetime.date(2199, 1, 11),
#   'sig_name': ['ABP', 'PLETH', 'I', 'II', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011486/p011486-2198-03-07-19-53.hea',
#   'subject_id': '011486',
#   'base_date': datetime.date(2198, 3, 7),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011756/p011756-2145-12-01-00-45.hea',
#   'subject_id': '011756',
#   'base_date': datetime.date(2145, 12, 1),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'AVL',
#    'AVF',
#    'V',
#    'MCL',
#    'RESP',
#    'PLETH',
#    'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011700/p011700-2167-12-05-21-15.hea',
#   'subject_id': '011700',
#   'base_date': datetime.date(2167, 12, 5),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p010694/p010694-2153-08-11-22-09.hea',
#   'subject_id': '010694',
#   'base_date': datetime.date(2153, 8, 11),
#   'sig_name': ['I',
#    'II',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'CVP',
#    'UAP',
#    'P4'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p012589/p012589-2103-12-10-16-47.hea',
#   'subject_id': '012589',
#   'base_date': datetime.date(2103, 12, 10),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'CVP', 'RAP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018971/p018971-2152-10-31-16-17.hea',
#   'subject_id': '018971',
#   'base_date': datetime.date(2152, 10, 31),
#   'sig_name': ['II', 'AVR', 'V', 'MCL', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018971/p018971-2152-10-29-09-29.hea',
#   'subject_id': '018971',
#   'base_date': datetime.date(2152, 10, 29),
#   'sig_name': ['I', 'II', 'III', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p013719/p013719-2148-11-26-02-21.hea',
#   'subject_id': '013719',
#   'base_date': datetime.date(2148, 11, 26),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'CVP',
#    'RAP',
#    'ART',
#    'PLETH R',
#    'AOBP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p015218/p015218-2126-11-01-14-40.hea',
#   'subject_id': '015218',
#   'base_date': datetime.date(2126, 11, 1),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p019093/p019093-2193-11-21-17-10.hea',
#   'subject_id': '019093',
#   'base_date': datetime.date(2193, 11, 21),
#   'sig_name': ['I',
#    'II',
#    'III',
#    'AVR',
#    'V',
#    'RESP',
#    'PLETH',
#    'ABP',
#    'PAP',
#    'CVP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p017875/p017875-2157-11-16-15-43.hea',
#   'subject_id': '017875',
#   'base_date': datetime.date(2157, 11, 16),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'P1', 'ICP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p017875/p017875-2157-11-28-17-06.hea',
#   'subject_id': '017875',
#   'base_date': datetime.date(2157, 11, 28),
#   'sig_name': ['II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p017875/p017875-2157-11-10-12-20.hea',
#   'subject_id': '017875',
#   'base_date': datetime.date(2157, 11, 10),
#   'sig_name': ['I', 'II', 'AVR', 'V', 'RESP', 'PLETH', 'ABP', 'PAP', 'ART'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p011861/p011861-2135-08-27-01-00.hea',
#   'subject_id': '011861',
#   'base_date': datetime.date(2135, 8, 27),
#   'sig_name': ['PLETH', 'II', 'V', 'I', 'III', 'ABP'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p018356/p018356-2161-02-01-22-06.hea',
#   'subject_id': '018356',
#   'base_date': datetime.date(2161, 2, 1),
#   'sig_name': ['PLETH', 'II', 'V', 'ABP', 'III'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p017913/p017913-2201-04-15-20-47.hea',
#   'subject_id': '017913',
#   'base_date': datetime.date(2201, 4, 15),
#   'sig_name': ['II', 'MCL', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p017913/p017913-2201-04-09-17-13.hea',
#   'subject_id': '017913',
#   'base_date': datetime.date(2201, 4, 9),
#   'sig_name': ['II', 'MCL', 'ABP', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p012110/p012110-2171-11-03-21-00.hea',
#   'subject_id': '012110',
#   'base_date': datetime.date(2171, 11, 3),
#   'sig_name': ['II', 'ABP', 'V', 'RESP', 'III', 'PLETH'],
#   'sig_len': 1},
#  {'record_name': '/root/Workspace/DataLake/mimic-iii_wfdb/p01/p012110/p012110-2172-02-21-17-10.hea',
#   'subject_id': '012110',
#   'base_date': datetime.date(2172, 2, 21),
#   'sig_name': ['I', 'PLETH', 'RESP', 'ABP', 'II', 'V'],
#   'sig_len': 1},
#  ...]

# %% [markdown]
# #### Save result by Pickle (feat. gzip)

# %%
# save and compress
with gzip.open('/root/Workspace/DataWarehouse/mimic-iii_wfdb/10_extracted_patient_records.pickle.gzip', 'wb') as f:
    pickle.dump(results, f)
